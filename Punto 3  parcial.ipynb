# %%
nombres1 = []
info1 = []

with open("archivo1.txt") as archivo1:
    for linea in archivo1.readlines():
        datos1 = linea
        datos1_sep = datos1.split(",")
        nombres1.append(datos1_sep[0])
        info = str(datos1_sep[1])
        info1.append(info.rstrip("\n"))

nombres2 = []
info2 = []

with open("archivo2.txt") as archivo2:
    for linea in archivo2.readlines():
        datos2 = linea
        datos2_sep = datos2.split(",")
        nombres2.append(datos2_sep[0])
        info = str(datos2_sep[1])
        info2.append(info.rstrip("\n"))
        
nombres3 = []
info3 = []

with open("archivo3.txt") as archivo3:
    for linea in archivo3.readlines():
        datos3 = linea
        datos3_sep = datos3.split(",")
        nombres3.append(datos3_sep[0])
        info = str(datos3_sep[1])
        info3.append(info.rstrip("\n"))

nombres4 = []
info4 = []

with open("archivo4.txt") as archivo4:
    for linea in archivo4.readlines():
        datos4 = linea
        datos4_sep = datos4.split(",")
        nombres4.append(datos4_sep[0])
        info = str(datos4_sep[1])
        info4.append(info.rstrip("\n"))

estudiantes = {}
for x in range(len(nombres1)):
    estudiantes[info1[x]] = {"Nombres" : nombres1[x], 
                               "e-mail" : info2[x],
                               "evaluación #1" : info3[x],
                               "evaluación #2" : info4[x]}

# %%
estudiantes
# Out:
# {'123412341': {'Nombres': 'ADRIANA PAOLA CUJAR ALARCON',
#   'e-mail': '1@gmail.com',
#   'evaluación #1': '1',
#   'evaluación #2': '63'},
#  '123412342': {'Nombres': 'ADRIANA GIRALDO GOMEZ',
#   'e-mail': '2@gmail.com',
#   'evaluación #1': '2',
#   'evaluación #2': '62'},
#  '123412343': {'Nombres': 'ADRIANA MARCELA SALCEDO SEGURA',
#   'e-mail': '3@gmail.com',
#   'evaluación #1': '3',
#   'evaluación #2': '61'},
#  '123412344': {'Nombres': 'ALEXANDER  DUARTE SANDOVAL',
#   'e-mail': '4@gmail.com',
#   'evaluación #1': '4',
#   'evaluación #2': '60'},
#  '123412345': {'Nombres': 'ALCIRA SANTANILLA CARVAJAL',
#   'e-mail': '5@gmail.com',
#   'evaluación #1': '5',
#   'evaluación #2': '59'},
#  '123412346': {'Nombres': 'AMPARO MONTOYA MONTOYA',
#   'e-mail': '6@gmail.com',
#   'evaluación #1': '6',
#   'evaluación #2': '58'},
#  '123412347': {'Nombres': 'ANA MARIA LOZANO SANTOS',
#   'e-mail': '7@gmail.com',
#   'evaluación #1': '7',
#   'evaluación #2': '57'},
# ...
